# %%
import pandas as pd
import numpy as np

# Loading Zomato.csv and country_code.csv
zomato_data = pd.read_csv('Zomato.csv')
country_code_data = pd.read_csv('Country-Code.csv')

# Merge datasets to map Country Code to Country Name
df = pd.merge(zomato_data, country_code_data, on='Country Code', how='left')





# Display the updated DataFrame
df.head(50)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
df.tail(20)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9531        6000747                 The Bigos           208     Ankara
# 9532        6002025                MasabaôÛ±           208     Ankara
# 9533        6003879               Zigana Pide           208     Ankara
# 9534        6004089               Dí_veroÛôlu           208     Ankara
# 9535        6000921               Dí_veroÛôlu           208     Ankara
# 9536        6004813           Pizza ÛÁl Forno           208     Ankara
# 9537        5904116       J'adore Chocolatier           208  ÛÁstanbul
# 9538        5901782                 Starbucks           208  ÛÁstanbul
# 9539        5902117                   Valonia           208  ÛÁstanbul
# 9540        5927248          Draft Gastro Pub           208  ÛÁstanbul
# 9541        5905215           Emirgan Sí_tiô           208  ÛÁstanbul
# 9542        5926979            Leman Kí_ltí_r           208  ÛÁstanbul
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
print("Min. Cost :", df['Average Cost for two'].min())
print("Max. Cost :", df['Average Cost for two'].max())
# Out:
# Min. Cost : 0
# Max. Cost : 800000

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
import pandas as pd

# Assuming df is your DataFrame
# Set display options to show all columns
pd.set_option('display.max_columns', None)

# Display first few rows with all columns visible
df.head(20)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)

# Drop rows with missing values (if any)
df.dropna(inplace=True)
# Out:
# Missing Values:
#  Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
# Drop unnecessary columns
columns_to_drop = ['Restaurant ID', 'Currency', 'Is delivering now', 'Switch to order menu']
df.drop(columns_to_drop, axis=1, inplace=True)
df
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546              NamlÛ± Gurme           208         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548                     Huqqa           208         ÛÁstanbul
# 9549              Aôôk Kahve           208         ÛÁstanbul
# 9550  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# ...

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Has Table booking', 'Has Online delivery',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Average Cost for two
plt.figure(figsize=(10, 6))
sns.histplot(df['Average Cost for two'], bins=20, kde=True)
plt.title('Distribution of Average Cost for Two')
plt.xlabel('Average Cost for Two')
plt.ylabel('Count')
plt.show()

# Distribution of Price range
plt.figure(figsize=(8, 5))
sns.countplot(x='Price range', data=df)
plt.title('Distribution of Price Range')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\yadav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Scatter plot of Average Cost for two vs. Aggregate rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Aggregate rating', y='Average Cost for two', data=df)
plt.title('Average Cost for Two vs. Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Average Cost for Two')
plt.show()

# Box plot of Price range vs. Rating text
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rating text', y='Price range', data=df, order=['Excellent', 'Very Good', 'Good', 'Average', 'Poor'])
plt.title('Price Range vs. Rating Text')
plt.xlabel('Rating Text')
plt.ylabel('Price Range')
plt.show()

# %%
# Select relevant features
selected_features = ['Restaurant Name', 'Country Code', 'City', 'Address', 'Locality',
       'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
       'Average Cost for two', 'Has Table booking', 'Has Online delivery',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
       'Votes', 'Country']

df1 = df[selected_features]
df1.head(50)
# Out:
#                              Restaurant Name  Country Code              City  \
# 0                           Le Petit Souffle           162       Makati City
# 1                           Izakaya Kikufuji           162       Makati City
# 2                     Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                                       Ooma           162  Mandaluyong City
# 4                                Sambo Kojin           162  Mandaluyong City
# 5                               Din Tai Fung           162  Mandaluyong City
# 6                                 Buffet 101           162        Pasay City
# 7                                    Vikings           162        Pasay City
# 8   Spiral - Sofitel Philippine Plaza Manila           162        Pasay City
# 9                                   Locavore           162        Pasig City
# 10                          Silantro Fil-Mex           162        Pasig City
# ...

# %%
df1 = df[selected_features].copy()

# Fill missing values in 'Average Cost for two' with mean
df1['Average Cost for two'].fillna(df1['Average Cost for two'].mean(), inplace=True)

# Initialize LabelEncoders for categorical columns
label_encoders = {}
categorical_columns = ['Restaurant Name', 'City', 'Address', 'Locality',
       'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
        'Aggregate rating', 'Rating color', 'Rating text',
        'Country']

for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    df1[col] = label_encoders[col].fit_transform(df1[col].astype(str))

# Convert boolean columns to integers (True=1, False=0)
bool_columns = ['Has Table booking', 'Has Online delivery']

# Replace 'Yes' and 'No' with 1 and 0
df1[bool_columns] = df1[bool_columns].replace({'Yes': 1, 'No': 0})

# %%
df1.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9542.000000   9542.000000  9542.000000  9542.000000  9542.000000
# mean       3648.654265     18.179208    77.570530  4538.486166   657.080277
# std        2140.178731     56.451600    22.781307  2563.438975   314.889244
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1775.250000      1.000000    78.250000  2321.250000   381.000000
# 50%        3590.500000      1.000000    87.000000  4606.500000   694.000000
# 75%        5478.750000      1.000000    87.000000  6740.750000   919.000000
# max        7436.000000    216.000000   139.000000  8909.000000  1205.000000
#
#        Locality Verbose    Longitude     Latitude     Cuisines  \
# count       9542.000000  9542.000000  9542.000000  9542.000000
# mean         676.259694  3913.365332  4115.164955   989.163173
# std          330.752100  2369.160941  2582.547172   514.326600
# ...

# %%
df1.corr()
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.020584 -0.001969  0.000623
# Country Code                 0.020584      1.000000 -0.178454 -0.217947
# City                        -0.001969     -0.178454  1.000000 -0.020604
# Address                      0.000623     -0.217947 -0.020604  1.000000
# Locality                     0.003963     -0.119186  0.094836  0.159403
# Locality Verbose             0.003916     -0.116678  0.091571  0.160363
# Longitude                    0.003768     -0.426603  0.227418  0.037409
# Latitude                     0.000535      0.184561  0.221546 -0.162518
# Cuisines                     0.051729     -0.135727  0.026584  0.024633
# Average Cost for two         0.019235      0.043717 -0.028306  0.022680
# Has Table booking            0.041148     -0.060815 -0.004039  0.006036
# Has Online delivery          0.028024     -0.153581  0.011926  0.029268
# ...

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Split data into train and test sets
x = df1.drop(['Average Cost for two'], axis=1)
y = df1['Average Cost for two']
print('Feature Dimension=', x.shape)
print('Label Dimension', y.shape)
# Out:
# Feature Dimension= (9542, 17)
# Label Dimension (9542,)

# %%
# REGRESSION ALGORITHIMS 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso, Ridge

# %%
# finding the best random state
maxAccu=0
maxRS=0
for i in range (1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS=i
print('Maximum r score is ', maxAccu,'On random_state ',maxRS )
# Out:
# Maximum r score is  0.08985693757707325 On random_state  82

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print(LR)
print('R2_score:',r2_score(y_test,pred_LR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_LR))
print("Mean Squared Error",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# LinearRegression()
# R2_score: 0.01186037306459753
# R2_score on training data: 4.689667276188869
# Mean Absolute Error: 2098.5067652136045
# Mean Squared Error 148035954.68952894
# Root Mean Squared Error: 12167.002699495424

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print(RFR)
print('R2_score:',r2_score(y_test,pred_RFR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_RFR))
print("Mean Squared Error",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# RandomForestRegressor()
# R2_score: 0.6519057772769083
# R2_score on training data: 93.58648384166077
# Mean Absolute Error: 335.8390499476074
# Mean Squared Error 52148966.78371052
# Root Mean Squared Error: 7221.424152043039

# %%
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print(GBR)
print('R2_score:',r2_score(y_test,pred_GBR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_GBR))
print("Mean Squared Error",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.2977058101151143
# R2_score on training data: 99.89516568428066
# Mean Absolute Error: 497.11848806300924
# Mean Squared Error 105212652.17847079
# Root Mean Squared Error: 10257.321881391399

# %%
Knn=KNN()
Knn.fit(x_train,y_train)
pred_Knn = Knn.predict(x_test)
pred_train = Knn.predict(x_train)
print(Knn)
print('R2_score:',r2_score(y_test,pred_Knn))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_Knn))
print("Mean Squared Error",mean_squared_error(y_test,pred_Knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_Knn)))
# Out:
# KNeighborsRegressor()
# R2_score: -0.08938044572515635
# R2_score on training data: 38.49201813266102
# Mean Absolute Error: 957.7275585050646
# Mean Squared Error 163203124.24184424
# Root Mean Squared Error: 12775.097817310216

# %%
# Performing Hyperparameter tuning.
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
# Define the hyperparameter grid
param_grid = {
    'n_estimators': [50, 100],
    'max_features': ['auto', 'sqrt'],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %%
model = RandomForestRegressor()
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [10, 20],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=2)

# %%
  best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}

# %%
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(x_test)
# Evaluate the tuned model
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
r2_tuned = r2_score(y_test, y_pred_tuned)

print(f"Tuned Model Mean Squared Error: {mse_tuned}")
print(f"Tuned Model R-squared: {r2_tuned*100}")
# Out:
# Tuned Model Mean Squared Error: 32649018.172265086
# Tuned Model R-squared: 78.20678854389746

# %% [markdown]
# So our model is performing well in predicting the Average price now lets lets perform the Classification task on price range.

# %%
from sklearn.preprocessing import StandardScaler



x = df1.drop("Price range", axis = 1) 
y = df1['Price range']

scaler = StandardScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %% [markdown]
# We have scaled the data using Standard Scalarization method to overcome the issue of biasness.

# %%
# finding the best random state
maxAccu=0
maxRS=0
for i in range (1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS=i
print('Maximum r score is ', maxAccu,'On random_state ',maxRS )
# Out:
# Maximum r score is  0.522664074380901 On random_state  86

# %%
#creating tain test split
x_train, x_test, y_train,y_test = train_test_split(x,y, test_size= .30, random_state= maxRS)

# %%
#CLASSFICATION ALGORITHMS
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test, predRFC))
print(classification_report(y_test, predRFC))
# Out:
# 0.9724065665385959
# [[1300    2    0    0]
#  [   7  934   17    1]
#  [   0   10  404    6]
#  [   1    0   35  146]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1302
#            2       0.99      0.97      0.98       959
#            3       0.89      0.96      0.92       420
#            4       0.95      0.80      0.87       182
#
#     accuracy                           0.97      2863
#    macro avg       0.96      0.93      0.94      2863
# weighted avg       0.97      0.97      0.97      2863

# %%
LR  = LogisticRegression()
LR.fit(x_train, y_train)
predLR = LR.predict(x_test)
print(accuracy_score(y_test, predLR))
print(confusion_matrix(y_test, predLR))
print(classification_report(y_test, predLR))
# Out:
# 0.7314006287111422
# [[1122  178    2    0]
#  [ 162  725   62   10]
#  [  39  123  238   20]
#  [  22   33  118    9]]
#               precision    recall  f1-score   support
#
#            1       0.83      0.86      0.85      1302
#            2       0.68      0.76      0.72       959
#            3       0.57      0.57      0.57       420
#            4       0.23      0.05      0.08       182
#
#     accuracy                           0.73      2863
#    macro avg       0.58      0.56      0.55      2863
# weighted avg       0.71      0.73      0.71      2863
# C:\Users\yadav\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
svc = SVC()
svc.fit(x_train, y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test, predsvc))
print(classification_report(y_test, predsvc))
# Out:
# 0.6776108976597974
# [[1284   18    0    0]
#  [ 500  446   13    0]
#  [  78  164  178    0]
#  [  52   12   86   32]]
#               precision    recall  f1-score   support
#
#            1       0.67      0.99      0.80      1302
#            2       0.70      0.47      0.56       959
#            3       0.64      0.42      0.51       420
#            4       1.00      0.18      0.30       182
#
#     accuracy                           0.68      2863
#    macro avg       0.75      0.51      0.54      2863
# weighted avg       0.70      0.68      0.64      2863

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train, y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test, predABC))
print(confusion_matrix(y_test, predABC))
print(classification_report(y_test, predABC))
# Out:
# 0.798812434509256
# [[1273   28    1    0]
#  [  20  916   16    7]
#  [   0  328   53   39]
#  [   0  114   23   45]]
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98      1302
#            2       0.66      0.96      0.78       959
#            3       0.57      0.13      0.21       420
#            4       0.49      0.25      0.33       182
#
#     accuracy                           0.80      2863
#    macro avg       0.68      0.58      0.57      2863
# weighted avg       0.78      0.80      0.76      2863

# %%
BC = BaggingClassifier()
BC.fit(x_train, y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test, predBC))
print(confusion_matrix(y_test, predBC))
print(classification_report(y_test, predBC))
# Out:
# 0.9769472581208523
# [[1296    6    0    0]
#  [   3  943   13    0]
#  [   0   15  400    5]
#  [   0    0   24  158]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1302
#            2       0.98      0.98      0.98       959
#            3       0.92      0.95      0.93       420
#            4       0.97      0.87      0.92       182
#
#     accuracy                           0.98      2863
#    macro avg       0.97      0.95      0.96      2863
# weighted avg       0.98      0.98      0.98      2863

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(RFC, x,y)
print(score)
print(score.mean())
print('Difference between Accuracy score and cross val score is - ', accuracy_score(y_test, predRFC)-score.mean())
# Out:
# [0.59979047 0.95966475 0.99213836 0.99842767 0.90041929]
# 0.8900881074201099
# Difference between Accuracy score and cross val score is -  0.08231845911848601

# %% [markdown]
# Random forest classifier is our best model as the diff between Accuracy and corss val score is the least.

# %%
#Hyper Parameter tuning 
#Random forst Classifier 
from sklearn.model_selection import GridSearchCV

parameters = {    'criterion': ['gini', 'entropy'],
    'random_state': [10, 20],
    'max_depth': [ 10, 20], 
    'n_jobs': [-2, 1], 
    'n_estimators': [10, 50] 
             }

# %%
GCV =GridSearchCV(RandomForestClassifier(), parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20], 'n_estimators': [10, 50],
#                          'n_jobs': [-2, 1], 'random_state': [10, 20]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 50,
#  'n_jobs': -2,
#  'random_state': 20}

# %%
Final_model = RandomForestClassifier(criterion= 'entropy', max_depth= 10, n_estimators= 50, n_jobs= -2, random_state= 10)
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test, pred)
print(acc*100)
# Out:
# 96.54208871812784

# %% [markdown]
# Conclusion So our classification model is showing 96.54percent accuracy in showing the predictions of the Price range. And on Regression model its showing 78percent accurany in predecting the Avg price.
