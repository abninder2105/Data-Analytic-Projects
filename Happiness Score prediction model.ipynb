# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# In this data we can clearly analyse that in this dataset continues values are present not the descret values, So its a Linear Regression model.

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
print('The Dimension of the dataset:',df.shape)
print('The Column header in the dataset:',df.columns)
# Out:
# The Dimension of the dataset: (158, 12)
# The Column header in the dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# This dataset contains 158 rows and 12 columns, Out of which 1 is our target variable and the remaning 11 is our independent variables.

# %%
min_happiness_score = df['Happiness Score'].min()
print("Minimum Happiness Score:", min_happiness_score)
max_happiness_score = df['Happiness Score'].max()
print("Maximum Happiness Score:", max_happiness_score)
# Out:
# Minimum Happiness Score: 2.839
# Maximum Happiness Score: 7.587

# %% [markdown]
# It's shows that dataset contains min. score 2.8 amd th maxi. score is 7.5.

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# There are 3 diff types of data(float64, int64, object) present in the dataset.

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# As we can see there is no null values are present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# This gives a breif about the dataset which includes indexing type, column type, no null values and memory usage.

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# We can clearly see that there is no null value is present.

# %%
df.nunique().to_frame('No. of unique values')
# Out:
#                                No. of unique values
# Country                                         158
# Region                                           10
# Happiness Rank                                  157
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Country
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: count, Length: 158, dtype: int64
#
#
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64
#
#
# Happiness Rank
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: count, Length: 157, dtype: int64
#
#
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# ...

# %% [markdown]
# No unique values, So we do not drop any columns.

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_country = LabelEncoder()
le_region = LabelEncoder()

df['Country'] = le_country.fit_transform(df['Country'])
df['Region'] = le_region.fit_transform(df['Region'])
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
print('total duplicate rows are', df.duplicated().sum())
# Out:
# total duplicate rows are 0

# %% [markdown]
# So, there is no duplicate rows present in the dataset

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    int32
#  1   Region                         158 non-null    int32
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# From the above discription we can observe the following things: The counts of all the columns are same which means there is no missing values in the dataset. The median(50%) and the mean in some of the columns is little skewed other than this the data is almost same os there is less to no skewness is present in these columns. In some of the columns it is shown that there is the little diff. between the 75% and max hence there are some outliers present in the data.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black', cmap='viridis')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %% [markdown]
# In this descriptive graph  we can check that data  is normal, no skewness and very less outliers are present.

# %%
sns.lmplot(x='Economy (GDP per Capita)', y= 'Happiness Score', data=df,  palette='colorblind')

# %% [markdown]
# Economy has a positive correlation with the Happiness score.

# %%
sns.lmplot(x="Freedom", y= 'Happiness Score', data=df,  palette='colorblind')

# %%
sns.lmplot(x="Health (Life Expectancy)", y= 'Happiness Score', data=df,  palette='colorblind')

# %%
sns.pairplot(data= df, palette = 'Dark2')

# %% [markdown]
# The pairplot gives the pairwise relation between the features. On the diagonal we can notice the distribution plots.

# %%
plt.figure(figsize=(12, 8))
df.boxplot()
plt.title('Boxplot of All Columns')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
z
# Out:
#       Country    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0    1.238770  1.300256        1.721000         1.937360        0.805926
# 1    0.449465  1.300256        1.699075         1.914581        0.055889
# 2    0.909893  1.300256        1.677149         1.884792        0.854487
# 3    0.581016  1.300256        1.655224         1.880411        0.531526
# 4    1.194920  0.040302        1.633299         1.797179        0.722845
# ..        ...       ...             ...              ...             ...
# 153  0.866043  0.965117        1.633576         1.674055        0.774917
# 154  1.436096  0.965117        1.655501         1.783571        0.662582
# 155  1.260695  0.375441        1.677427         2.076199        0.132534
# 156  1.260695  0.965117        1.699352         2.164688        2.263962
# 157  1.370321  0.965117        1.721277         2.222513        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %% [markdown]
# First array is giving the rows of outliers and second array is giving the columns having outliers

# %%
df1= df[(z<3).all(axis=1)]
print("New Data Frame:",df1.shape)
print("Old Data Frame:",df.shape)
# Out:
# New Data Frame: (149, 12)
# Old Data Frame: (158, 12)

# %% [markdown]
# Now it has only 149 rows and 12 columns.

# %%
print("Data loss Perc%", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss Perc% 5.69620253164557

# %% [markdown]
# Data loss is in acceptable range.

# %%
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
plt.figure(figsize=(20,25), facecolor="green")
plotnumber = 1
for column in df1:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df1[column], color ='b')
        plt.xlabel(column, fontsize= 20)
    plotnumber+=1
plt.show()

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Country
# 135    1
# 10     1
# 51     1
# 77     1
# 57     1
#       ..
# 70     1
# 125    1
# 81     1
# 101    1
# 141    1
# Name: count, Length: 158, dtype: int64
#
#
# Region
# 8    40
# 1    29
# 3    22
# 9    21
# 4    20
# 6     9
# 7     7
# 2     6
# 5     2
# 0     2
# Name: count, dtype: int64
#
#
# Happiness Rank
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: count, Length: 157, dtype: int64
#
#
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: count, Length: 157, dtype: int64
#
#
# Standard Error
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# 0.04251    1
# 0.03843    1
# 0.05371    1
# 0.06727    1
# Name: count, Length: 153, dtype: int64
#
#
# Economy (GDP per Capita)
# 1.39651    1
# 0.39753    1
# ...

# %%
df1.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
df1['Standard Error']= np.cbrt(df1['Standard Error'])

# %%
df1['Trust (Government Corruption)']= np.cbrt(df1['Trust (Government Corruption)'])

# %%
df1.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
df1.corr
# Out:
# <bound method DataFrame.corr of      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587        0.324310
# 1         58       9               2            7.561        0.365532
# 2         37       9               3            7.527        0.321658
# 3        105       9               4            7.522        0.338540
# 4         24       5               5            7.427        0.328749
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655        0.371834
# 151       20       8             152            3.587        0.350990
# 152        0       7             153            3.575        0.313597
# 154       13       8             155            3.340        0.331896
# 156       21       8             157            2.905        0.442391
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# This gives the correlation between the dependent and independent variables.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df1.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black', cmap='viridis')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %%
# Seperating the independent variables and atarget variables into x and y
x= df1.drop(['Happiness Score', 'Country'], axis=1)
y = df1['Happiness Score']

print('Feature Dimension=', x.shape)
print('Label Dimension', y.shape)
# Out:
# Feature Dimension= (149, 10)
# Label Dimension (149,)

# %%
#lINEAR REGRESSION ALGORITHIMS 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso, Ridge

# %%
# finding the best random state
maxAccu=0
maxRS=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS=i
print('Maximum r score is ', maxAccu,'On random_state ',maxRS)
# Out:
# Maximum r score is  0.999527064130234 On random_state  194

# %%
 x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=maxRS)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print(LR)
print('R2_score:',r2_score(y_test,pred_LR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_LR))
print("Mean Squared Error",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# LinearRegression()
# R2_score: 0.999527064130234
# R2_score on training data: 99.86637699605328
# Mean Absolute Error: 0.019935721082921246
# Mean Squared Error 0.0007336790666166127
# Root Mean Squared Error: 0.027086510787043293

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color= 'r')
plt.plot(pred_LR, pred_LR,color='b')
plt.xlabel('Actual', fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print(RFR)
print('R2_score:',r2_score(y_test,pred_RFR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_RFR))
print("Mean Squared Error",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# RandomForestRegressor()
# R2_score: 0.989369138914624
# R2_score on training data: 99.95675212392949
# Mean Absolute Error: 0.05588222222222269
# Mean Squared Error 0.017292308239999825
# Root Mean Squared Error: 0.1315002214446798

# %%
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print(GBR)
print('R2_score:',r2_score(y_test,pred_GBR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_GBR))
print("Mean Squared Error",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.9916235268737215
# R2_score on training data: 99.99993615829406
# Mean Absolute Error: 0.05428052581547796
# Mean Squared Error 0.013625289061761792
# Root Mean Squared Error: 0.11672741349726633

# %%
Knn=KNN()
Knn.fit(x_train,y_train)
pred_Knn = Knn.predict(x_test)
pred_train = Knn.predict(x_train)
print(Knn)
print('R2_score:',r2_score(y_test,pred_Knn))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_Knn))
print("Mean Squared Error",mean_squared_error(y_test,pred_Knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_Knn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.9900388648145896
# R2_score on training data: 99.86517258058635
# Mean Absolute Error: 0.050133333333333426
# Mean Squared Error 0.016202922666666685
# Root Mean Squared Error: 0.12729070141478005

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print(lasso)
print('R2_score:',r2_score(y_test,pred_lasso))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_lasso))
print("Mean Squared Error",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# Lasso()
# R2_score: 0.9827778853562783
# R2_score on training data: 98.52594343725899
# Mean Absolute Error: 0.1231333327382907
# Mean Squared Error 0.02801373403077601
# Root Mean Squared Error: 0.16737303854198265

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(GBR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-3.493751    0.09951209 -0.12190672 -0.30522492 -2.24650168]
# -1.2135744443879668
# Difference between R2 score and Cross Validation Score is 220.5197971261688

# %%
score1 = cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-3.51254472  0.1275819  -0.12268015 -0.30506981 -2.27418287]
# -1.2173791304490855
# Difference between R2 score and Cross Validation Score is 220.75013378272854

# %%
score3 = cross_val_score(lasso,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [-3.493751    0.09951209 -0.12190672 -0.30522492 -2.24650168]
# -1.2135744443879668
# Difference between R2 score and Cross Validation Score is 219.63523297442453

# %% [markdown]
# Here our diff between R2 score and cross validation score is too high, the possible cause is there is some degree of overfitting in the model. To overcome this overfitting we will use certain techniques to reduse it.

# %%
# We are Regularizing using  lasso.
from sklearn.linear_model import Lasso
alpha = 0.1  # Adjust alpha as needed
model = Lasso(alpha=alpha)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
selector = SelectFromModel(Lasso(alpha=0.1))
selector.fit(x_train, y_train)
x_train_selected = selector.transform(x_train)
x_test_selected = selector.transform(x_test)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, x_train, y_train, cv=5)
print(score)
# Out:
# [-3.493751    0.09951209 -0.12190672 -0.30522492 -2.24650168]

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()

# %%
#Using Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
param_grid = {'alpha': [0.1, 0.5, 1.0]}
gscv = GridSearchCV(model, param_grid, cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'alpha': [0.1, 0.5, 1.0]})

# %%
best_model = gscv.best_estimator_
best_params = gscv.best_params_

# Print the best hyperparameters
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'alpha': 0.1}

# %%
Model= Ridge(alpha= 0.1)

# %%
Model.fit(x_train,y_train)
pred_Model = Model.predict(x_test)
print('R2_score:',r2_score(y_test,pred_Model))
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_Model))
print("Mean Squared Error",mean_squared_error(y_test,pred_Model))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_Model)))
# Out:
# R2_score: 0.9983954304793711
# Mean Absolute Error: 0.03770646185547994
# Mean Squared Error 0.0024892150151328194
# Root Mean Squared Error: 0.04989203358385805

# %%
import pickle
filename= 'happiness_score_prediction.pkl'
pickle.dump(Model, open(filename, 'wb'))###too save the model

# %%
import pickle 
loaded_model = pickle.load(open('happiness_score_prediction.pkl','rb'))
result = loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.83954304793711

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Orignal'])
conclusion
# Out:
#                  0         1         2         3         4         5   \
# Predicted  3.679751  5.095506  3.700817  7.219192  7.324724  6.938902
# Orignal    3.667000  5.102000  3.681000  7.278000  7.378000  6.937000
#
#                  6         7         8         9   ...       35        36  \
# Predicted  4.291963  4.204078  4.721908  7.464802  ...  4.04688  6.045663
# Orignal    4.369000  4.292000  4.739000  7.587000  ...  4.03300  6.003000
#
#                  37        38        39        40       41        42  \
# Predicted  5.712476  7.178388  3.609601  5.118516  5.83697  4.337543
# Orignal    5.716000  7.286000  3.587000  5.123000  5.82400  4.332000
#
#                  43        44
# Predicted  7.148539  3.666528
# Orignal    7.226000  3.655000
#
# [2 rows x 45 columns]

# %% [markdown]
# Here you can compare the predicted and the original values.
