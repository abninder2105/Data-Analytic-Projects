# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# In this data we can clearly analyse that in this dataset continues values are present not the descret values, So its a Linear Regression model.

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset contain 30 rows and 17 columns.

# %%
df.columns
print('The Dimension of the dataset:',df.shape)
print('The Column header in the dataset:',df.columns)
# Out:
# The Dimension of the dataset: (30, 17)
# The Column header in the dataset: Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# This dataset contains 30 rows and 17 columns, Out of which 1 is our target variable and the remaning 16 is our independent variables.

# %%
min_win = df['W'].min()
print("Minimum  Win:", min_win)
max_win = df['W'].max()
print("Maximum win:", max_win)
# Out:
# Minimum  Win: 63
# Maximum win: 100

# %% [markdown]
# It shows that dataset contains min win of 63 and max win of 100.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# This dataset contain only two data types i.e int64, float64.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no null value present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.nunique().to_frame('No. of unique values')
# Out:
#      No. of unique values
# W                      24
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %% [markdown]
# So this shows no. of unique values each column contain.

# %%
print('total duplicate rows are', df.duplicated().sum())
# Out:
# total duplicate rows are 0

# %% [markdown]
# There is no duplicate rows are present in the dataset.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# From the above discription we can observe the following things: The counts of all the columns are same which means there is no missing values in the dataset. The median(50%) is greater than the mean in most of the columns it shows that the data is skewed to the left. In some of the columns it is shown that there is the diff. between the 75% and max hence there are some outliers present in the data.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black', cmap='viridis')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# This is visual repersentation of the df.describe().

# %%
#Distribution of wins
plt.figure(figsize=(10, 6))
sns.histplot(df['W'], bins=30, kde=True)
plt.title('Distribution of Win')
plt.xlabel('Win')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(20,25), facecolor="green")
plotnumber = 1
for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column], color ='b')
        plt.xlabel(column, fontsize= 20)
    plotnumber+=1
plt.show()

# %% [markdown]
# This shows that the data looks normal in all the columns.

# %%
sns.lmplot(x='W', y='R', data=df,palette='colorblind')

# %% [markdown]
# It shows that there are some postive and some negative residual are there and the line overestimating the acutal data value for y.

# %%
sns.lmplot(x='W', y='AB', data=df,palette='colorblind')

# %%
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# So we have found outlier in all the columns. So we will remove the outliers using the zscore and IQR techniques before building the model and selecting the best one.

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
#putting thrushold = 3 then 99.7% of the data comes under the bell-shaped curve
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %% [markdown]
# First array is giving the rows of outliers and second array is giving the columns having outliers.

# %%
#Now we will remove the data above zscore and creating new DF.
df1= df[(z<3).all(axis=1)]
print("New Data Frame:",df1.shape)
print("Old Data Frame:",df.shape)
# Out:
# New Data Frame: (29, 17)
# Old Data Frame: (30, 17)

# %%
print("Data loss Perc%", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss Perc% 3.3333333333333335

# %%
df1.skew()
# Out:
# W      0.119013
# R     -0.329729
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# The data is in acceptable range.

# %%
df1.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.396810 -0.085780 -0.018360  0.384886 -0.206737  0.245697
# R    0.396810  1.000000  0.437170  0.429926  0.475067  0.139017  0.590464
# AB  -0.085780  0.437170  1.000000  0.769159  0.490752  0.445604 -0.064653
# H   -0.018360  0.429926  0.769159  1.000000  0.528016  0.582024 -0.218711
# 2B   0.384886  0.475067  0.490752  0.528016  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.139017  0.445604  0.582024  0.342419  1.000000 -0.369299
# HR   0.245697  0.590464 -0.064653 -0.218711 -0.098695 -0.369299  1.000000
# BB   0.447513  0.259217 -0.137850 -0.222271  0.211243 -0.404852  0.336814
# SO   0.156469  0.090591 -0.111243 -0.371861 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.074056  0.373674  0.417877  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.023950  0.315499  0.244606 -0.215196  0.312750 -0.092586
# ER  -0.815308 -0.002549  0.309146  0.280571 -0.224993  0.333731 -0.062094
# ...

# %% [markdown]
# This gives the correlation between the dependent and independent variables.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df1.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black', cmap='viridis')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %%
# Seperating the independent variables and atarget variables into x and y
x = df1.drop("W", axis= 1 )
y = df1['W']

print('Feature Dimension=', x.shape)
print('Label Dimension', y.shape)
# Out:
# Feature Dimension= (29, 16)
# Label Dimension (29,)

# %%
# REGRESSION ALGORITHIMS 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso, Ridge

# %% [markdown]
# Creating train test split

# %%
# finding the best random state
maxAccu=0
maxRS=0
for i in range (1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS=i
print('Maximum r score is ', maxAccu,'On random_state ',maxRS )
# Out:
# Maximum r score is  0.7879450140498971 On random_state  62

# %%
 x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=maxRS)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print(LR)
print('R2_score:',r2_score(y_test,pred_LR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_LR))
print("Mean Squared Error",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# LinearRegression()
# R2_score: 0.7879450140498971
# R2_score on training data: 98.77637317855876
# Mean Absolute Error: 3.911410004713928
# Mean Squared Error 22.29457111544539
# Root Mean Squared Error: 4.7217127311437945

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color= 'r')
plt.plot(pred_LR, pred_LR,color='b')
plt.xlabel('Actual', fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print(RFR)
print('R2_score:',r2_score(y_test,pred_RFR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_RFR))
print("Mean Squared Error",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# RandomForestRegressor()
# R2_score: 0.6959954086425552
# R2_score on training data: 93.30185934886427
# Mean Absolute Error: 4.445555555555554
# Mean Squared Error 31.96176666666667
# Root Mean Squared Error: 5.653473858316378

# %%
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print(GBR)
print('R2_score:',r2_score(y_test,pred_GBR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_GBR))
print("Mean Squared Error",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.43901652068512476
# R2_score on training data: 99.99999913454675
# Mean Absolute Error: 6.421734529311517
# Mean Squared Error 58.97944826969726
# Root Mean Squared Error: 7.679807827654105

# %%
Knn=KNN()
Knn.fit(x_train,y_train)
pred_Knn = Knn.predict(x_test)
pred_train = Knn.predict(x_train)
print(Knn)
print('R2_score:',r2_score(y_test,pred_Knn))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_Knn))
print("Mean Squared Error",mean_squared_error(y_test,pred_Knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_Knn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.598529826209488
# R2_score on training data: 35.93173498824274
# Mean Absolute Error: 5.133333333333334
# Mean Squared Error 42.20888888888889
# Root Mean Squared Error: 6.496836837176142

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print(lasso)
print('R2_score:',r2_score(y_test,pred_lasso))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_lasso))
print("Mean Squared Error",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# Lasso()
# R2_score: 0.597155729515721
# R2_score on training data: 94.77328991981851
# Mean Absolute Error: 5.036849113540324
# Mean Squared Error 42.353355647458265
# Root Mean Squared Error: 6.507945578095922

# %% [markdown]
# We will check for cross validation score.

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(GBR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [ 0.05664406 -9.15045129  0.49071961  0.59725127  0.87813923]
# -1.4255394228618266
# Difference between R2 score and Cross Validation Score is 186.45559435469514

# %%
score1 = cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [ 0.05664406 -9.15045129  0.49071961  0.59725127  0.87813923]
# -1.4255394228618266
# Difference between R2 score and Cross Validation Score is 212.15348315043818

# %%
score2 = cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.05664406 -9.15045129  0.49071961  0.59725127  0.87813923]
# -1.4255394228618266
# Difference between R2 score and Cross Validation Score is 221.3484436911724

# %%
score3 = cross_val_score(Knn,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_Knn)-score.mean())*100)
# Out:
# [ 0.05664406 -9.15045129  0.49071961  0.59725127  0.87813923]
# -1.4255394228618266
# Difference between R2 score and Cross Validation Score is 202.40692490713147

# %%
score3 = cross_val_score(lasso,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.05664406 -9.15045129  0.49071961  0.59725127  0.87813923]
# -1.4255394228618266
# Difference between R2 score and Cross Validation Score is 202.26951523775477

# %% [markdown]
# From the diff of both r2 score and cross validation score computed on r2 score we conclude that LinearRegresion is our best fit and now we use hyper paramter to get the best model.

# %%
# Performing Hyperparameter tuning.
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Define hyperparameters to tune


param_grid = {
    'fit_intercept': [True, False],
    'copy_X': [True, False]
}

model = LinearRegression()
grid_search = GridSearchCV(model, param_grid, cv=5)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False]})

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'copy_X': True, 'fit_intercept': True}

# %%
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(x_test)
# Evaluate the tuned model
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
r2_tuned = r2_score(y_test, y_pred_tuned)

print(f"Tuned Model Mean Squared Error: {mse_tuned}")
print(f"Tuned Model R-squared: {r2_tuned}")
# Out:
# Tuned Model Mean Squared Error: 22.29457111544539
# Tuned Model R-squared: 0.7879450140498971

# %%
import pickle
filename= 'winn_prediction.pkl'
pickle.dump(best_model, open(filename, 'wb'))###too save the model

# %%
import pickle 
loaded_model = pickle.load(open('winn_prediction.pkl','rb'))
result = loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 78.79450140498972

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Orignal'])
conclusion
# Out:
#                    0          1          2          3         4          5  \
# Predicted  89.979709  94.600703  86.794252  96.765304  81.86963  84.596392
# Orignal    80.000000  97.000000  83.000000  98.000000  76.00000  81.000000
#
#                    6          7          8
# Predicted  58.609203  81.394187  77.543732
# Orignal    63.000000  81.000000  74.000000

# %%
So, the r2 score on test data is 78%. So it measn the accuracy of our model on test data is 78%.
