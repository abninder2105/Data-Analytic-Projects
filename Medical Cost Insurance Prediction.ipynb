# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df =  pd.read_csv('medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns

print("The Dimensions of the dataset:",df.shape)
print("The column headers in the dataset:",df.columns)
# Out:
# The Dimensions of the dataset: (1338, 7)
# The column headers in the dataset: Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# This Dataset contains 1338 rows and 7 columns. Out of which 1 is the target variable and the remaining 6 are independent variables.

# %%
print("Min. Charges :", df.charges.min())
print("Max. Charges :", df.charges.max())
# Out:
# Min. Charges : 1121.8739
# Max. Charges : 63770.42801

# %% [markdown]
# Its shows that the dataset contains min. charges 1121.87 and max charges 637770.42.

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# There are 3 diff types of data(float64,int64,object) present in the dataset.

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# As we can see there is no null values are present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# This gives a breif about the dataset which includes indexing type, column type, no null values and memory usage.

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# We can clearly see that there is no null values are present.

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#           No. of unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64
#
#
# sex
# male      676
# female    662
# Name: count, dtype: int64
#
#
# bmi
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: count, Length: 548, dtype: int64
#
#
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64
#
#
# smoker
# no     1064
# yes     274
# ...

# %% [markdown]
# There is no same data present in any of the columns so we do not drop any column.

# %%
print("Total Duplicate Rows are", df.duplicated().sum())
# Out:
# Total Duplicate Rows are 1

# %% [markdown]
# So there are 1 duplicate rows are present and we will drop the duplicate rows and keep the unique values in the dataset

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
print("Total Duplicate Rows are", df.duplicated().sum())
# Out:
# Total Duplicate Rows are 0

# %% [markdown]
# Now we have removed the duplicate row as its showing 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %% [markdown]
# As you can see intially there were 1338 rows were there now its only showing 1337 rows.

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# From the above discription we can observe the following things:
# The counts of all the columns are same which means there is no missing values in the dataset.
# The median(50%) value is less than the mean in some of the columns which means the data is little skewed to the right in these columns.
# In some of the columns it is shown that there is the huge diff between the 75% and max hence there are outliers present in the data.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black', cmap='viridis')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %%
sns.lmplot(x='age', y='', data=df,palette='colorblind')

# %% [markdown]
# It shows that there are some postive and some negative residual are there and the line overestimating the acutal data value for y.

# %%
sns.lmplot(x='bmi', y='charges', data=df,palette='colorblind')

# %% [markdown]
# charges has a high corelation with the bmi.

# %%
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# So we have found outlier in all the columns. So we will remove the outliers using the zscore and IQR techniques before building the model and selecting the best one.

# %%
from scipy.stats import zscore
out_features = df[['age', 'bmi', 'children' ]]
z = np.abs(zscore(out_features))
z
# Out:
#            age       bmi  children
# 0     1.440418  0.453160  0.909234
# 1     1.511647  0.509422  0.079442
# 2     0.799350  0.383155  1.580143
# 3     0.443201  1.305052  0.909234
# 4     0.514431  0.292456  0.909234
# ...        ...       ...       ...
# 1333  0.767704  0.050269  1.580143
# 1334  1.511647  0.206053  0.909234
# 1335  1.511647  1.014490  0.909234
# 1336  1.297958  0.797524  0.909234
# 1337  1.551231  0.261299  0.909234
#
# [1337 rows x 3 columns]

# %%
#putting thrushold = 3 then 99.7% of the data comes under the bell-shaped curve
np.where(z>3)
# Out:
# (array([  32,   71,  116,  166,  413,  425,  438,  568,  639,  846,  876,
#          931,  936,  968,  983, 1046, 1084, 1115, 1129, 1244, 1271, 1316],
#        dtype=int64),
#  array([2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1],
#        dtype=int64))

# %% [markdown]
# First array is giving the rows of outliers and second array is giving the columns having outliers

# %%
#Now we will remove the data above zscore and creating new DF.
df1= df[(z<3).all(axis=1)]
print("New Data Frame:",df1.shape)
print("Old Data Frame:",df.shape)
# Out:
# New Data Frame: (1315, 9)
# Old Data Frame: (1337, 9)

# %% [markdown]
# Now it has only 1315 rows and 9 columns.

# %%
print("Data loss Perc%", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss Perc% 1.6454749439042633

# %%
df1
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# ...

# %%
plt.figure(figsize=(20,25), facecolor="green")
plotnumber = 1
for column in df1:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df1[column], color ='b')
        plt.xlabel(column, fontsize= 20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distribution plots we can notice that the data almost looks normal in all the columns.

# %%
df1.skew()
# Out:
# age                 0.048993
# bmi                 0.193481
# children            0.739818
# charges             1.500552
# sex_male           -0.010659
# smoker_yes          1.449184
# region_northwest    1.183218
# region_southeast    1.041888
# region_southwest    1.212127
# dtype: float64

# %%
df1['charges']= np.cbrt(df['charges'])

# %%
df1['smoker_yes']= np.cbrt(df['smoker_yes'])

# %%
df1['region_southwest']= np.cbrt(df['region_southwest'])

# %%
df1['region_southeast']= np.cbrt(df['region_southeast'])

# %%
df1.skew()
# Out:
# age                 0.048993
# bmi                 0.193481
# children            0.739818
# charges             0.507326
# sex_male           -0.010659
# smoker_yes          1.449219
# region_northwest    1.183218
# region_southeast    1.041016
# region_southwest    1.211914
# dtype: float64

# %%
df1.corr()
# Out:
#                        age       bmi  children   charges  sex_male  \
# age               1.000000  0.119151  0.057365  0.450298 -0.016603
# bmi               0.119151  1.000000  0.027712  0.164151  0.039952
# children          0.057365  0.027712  1.000000  0.143337  0.016028
# charges           0.450298  0.164151  0.143337  1.000000  0.031320
# sex_male         -0.016603  0.039952  0.016028  0.031320  1.000000
# smoker_yes       -0.026334  0.004987  0.025060  0.732651  0.079891
# region_northwest -0.001574 -0.133869  0.048335 -0.027608 -0.008337
# region_southeast -0.013383  0.260769 -0.029917  0.038796  0.013914
# region_southwest  0.013431  0.001984  0.000029 -0.042823 -0.001222
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.026334         -0.001574         -0.013383
# bmi                 0.004987         -0.133869          0.260769
# children            0.025060          0.048335         -0.029917
# ...

# %% [markdown]
# This gives the correlation between the dependent and independent variables.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df1.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black', cmap='viridis')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %%
# Seperating the independent variables and atarget variables into x and y
x = df1.drop("charges", axis= 1 )
y = df1['charges']

print('Feature Dimension=', x.shape)
print('Label Dimension', y.shape)
# Out:
# Feature Dimension= (1315, 8)
# Label Dimension (1315,)

# %%
#lINEAR RIGRESSION ALGORITHIMS 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso, Ridge

# %% [markdown]
# Creating train test split

# %%
# finding the best random state
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS=i
print('Maximum r score is ', maxAccu,'On random_state ',maxRS)
# Out:
# Maximum r score is  0.8384157315066286 On random_state  38

# %%
  x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=maxRS)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print(LR)
print('R2_score:',r2_score(y_test,pred_LR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_LR))
print("Mean Squared Error",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# LinearRegression()
# R2_score: 0.8384157315066286
# R2_score on training data: 75.3850175507227
# Mean Absolute Error: 1.887646074269057
# Mean Squared Error 7.32503476993651
# Root Mean Squared Error: 2.706480144012978

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color= 'r')
plt.plot(pred_LR, pred_LR,color='b')
plt.xlabel('Actual', fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print(RFR)
print('R2_score:',r2_score(y_test,pred_RFR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_RFR))
print("Mean Squared Error",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# RandomForestRegressor()
# R2_score: 0.8486336310935523
# R2_score on training data: 96.94110186223699
# Mean Absolute Error: 1.5921561548422813
# Mean Squared Error 6.861830830296767
# Root Mean Squared Error: 2.6195096545530743

# %%
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print(GBR)
print('R2_score:',r2_score(y_test,pred_GBR))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_GBR))
print("Mean Squared Error",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.8823933088398523
# R2_score on training data: 87.09254145659153
# Mean Absolute Error: 1.3820151731219839
# Mean Squared Error 5.331416913030775
# Root Mean Squared Error: 2.3089861223122963

# %%
Knn=KNN()
Knn.fit(x_train,y_train)
pred_Knn = Knn.predict(x_test)
pred_train = Knn.predict(x_train)
print(Knn)
print('R2_score:',r2_score(y_test,pred_Knn))
print("R2_score on training data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_Knn))
print("Mean Squared Error",mean_squared_error(y_test,pred_Knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_Knn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.27898356509879785
# R2_score on training data: 47.8296789605054
# Mean Absolute Error: 4.214385852794038
# Mean Squared Error 32.68554856603277
# Root Mean Squared Error: 5.717127649968362

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(GBR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [0.86308454 0.75001187 0.88578461 0.83184105 0.82096523]
# 0.8303374605279468
# Difference between R2 score and Cross Validation Score is 5.205584831190557

# %%
score1 = cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [0.86308454 0.75001187 0.88578461 0.83184105 0.82096523]
# 0.8303374605279468
# Difference between R2 score and Cross Validation Score is 1.8296170565605507

# %%
score2 = cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.86308454 0.75001187 0.88578461 0.83184105 0.82096523]
# 0.8303374605279468
# Difference between R2 score and Cross Validation Score is 0.8078270978681856

# %%
score3 = cross_val_score(Knn,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and Cross Validation Score is",(r2_score(y_test,pred_Knn)-score.mean())*100)
# Out:
# [0.86308454 0.75001187 0.88578461 0.83184105 0.82096523]
# 0.8303374605279468
# Difference between R2 score and Cross Validation Score is -55.13538954291489

# %% [markdown]
# From the diff of both r2 score and cross validation score computed on r2 score we conclude that GradiantBoostingRegresion is our best fitting and best performing model

# %%
model1=GBR.fit(x_train, y_train)
pred= GBR.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test, pred))
print("Mean Squared Error",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_score: 0.8823868231079992
# Mean Absolute Error: 1.3818742675040965
# Mean Squared Error 5.3317109281089525
# Root Mean Squared Error: 2.309049789006065

# %%
import pickle
filename= 'medical_cost_insurance_prediction.pkl'
pickle.dump(model1, open(filename, 'wb'))###too save the model

# %%
import pickle 
loaded_model = pickle.load(open('medical_cost_insurance_prediction.pkl','rb'))
result = loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 88.23868231079992

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Orignal'])
conclusion
# Out:
#                  0          1          2          3          4          5    \
# Predicted  22.611799  16.387567  16.401722  16.753559  23.445515  30.083049
# Orignal    21.939567  14.206331  14.853630  16.069665  28.101856  30.402477
#
#                  6          7          8          9    ...        385  \
# Predicted  13.584185  15.239171  13.737079  19.680885  ...  21.728170
# Orignal    11.982274  14.457361  12.876345  19.704638  ...  20.666859
#
#                  386        387        388        389        390        391  \
# Predicted  33.835276  25.942049  26.816739  12.720304  15.903198  19.054262
# Orignal    34.084394  26.573960  27.625175  11.852357  15.517448  19.170668
#
#                  392        393        394
# Predicted  12.748672  22.322736  27.141237
# Orignal    10.437301  21.383977  27.250012
#
# [2 rows x 395 columns]
